# %% [markdown]
# <a href="https://colab.research.google.com/github/GenHavoc/DeepFLow/blob/main/Minor_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel("data.xlsx")

# %%
df.head()
# Out:
#                     name online_order book_table  Rating  votes      location  \
# 0                  Jalsa          Yes        Yes     4.1    775  Banashankari
# 1         Spice Elephant          Yes         No     4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No     3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No     3.7     88  Banashankari
# 4          Grand Village           No         No     3.8    166  Basavanagudi
#
#              rest_type                        cuisines  \
# 0        Casual Dining  North Indian, Mughlai, Chinese
# 1        Casual Dining     Chinese, North Indian, Thai
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian
# 3          Quick Bites      South Indian, North Indian
# 4        Casual Dining        North Indian, Rajasthani
#
#    approx_cost(for two people) listed_in(type) listed_in(city)
# 0                          800          Buffet    Banashankari
# 1                          800          Buffet    Banashankari
# 2                          800          Buffet    Banashankari
# 3                          300          Buffet    Banashankari
# 4                          600          Buffet    Banashankari

# %%
df.isnull().mean()
# Out:
# name                           0.0
# online_order                   0.0
# book_table                     0.0
# Rating                         0.0
# votes                          0.0
# location                       0.0
# rest_type                      0.0
# cuisines                       0.0
# approx_cost(for two people)    0.0
# listed_in(type)                0.0
# listed_in(city)                0.0
# dtype: float64

# %%
df.shape
# Out:
# (41263, 11)

# %%
duplicate_mask = df.duplicated()
duplicate_mask.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df[duplicate_mask]
# Out:
#                                   name online_order book_table  Rating  votes  \
# 1758                        Shiv Sagar           No         No     3.6     10
# 3024             The Fisherman's Wharf          Yes        Yes     4.4   4099
# 3941                         OPUS Club           No        Yes     4.4   1496
# 3942                             Float          Yes        Yes     4.4   3061
# 3960                             Float          Yes        Yes     4.4   3061
# ...                                ...          ...        ...     ...    ...
# 34974  Alchemy - The Chancery Pavilion           No        Yes     4.3    485
# 36763    Tipsy Bull - The Bar Exchange           No        Yes     4.6   3173
# 36764       BTDT? Been There Done That           No        Yes     4.3    962
# 38988                     ShakesBierre           No        Yes     4.4    409
# 39373        Sri Ganesh Juice Junction          Yes         No     3.5      6
#
#                 location                    rest_type  \
# 1758   Bannerghatta Road                   Food Court
# 3024       Sarjapur Road           Casual Dining, Bar
# 3941       Sarjapur Road                          Pub
# 3942        Marathahalli           Casual Dining, Bar
# 3960        Marathahalli           Casual Dining, Bar
# ...                  ...                          ...
# 34974     Residency Road  Microbrewery, Casual Dining
# 36763        Indiranagar           Bar, Casual Dining
# 36764        Indiranagar           Bar, Casual Dining
# 38988       Brigade Road  Microbrewery, Casual Dining
# 39373          Bellandur                Beverage Shop
#
#                                               cuisines  \
# 1758                           South Indian, Beverages
# 3024   Seafood, Goan, North Indian, Continental, Asian
# 3941       Continental, Italian, North Indian, Mexican
# 3942                            North Indian, Japanese
# 3960                            North Indian, Japanese
# ...                                                ...
# 34974                                    Modern Indian
# 36763      Chinese, Continental, North Indian, Mexican
# 36764        European, Continental, Asian, Finger Food
# 38988       Asian, Continental, European, North Indian
# 39373                                Juices, Fast Food
#
#        approx_cost(for two people)     listed_in(type)    listed_in(city)
# 1758                           400            Dine-out  Bannerghatta Road
# 3024                          1400              Buffet          Bellandur
# 3941                          1900  Drinks & nightlife          Bellandur
# 3942                          1500  Drinks & nightlife          Bellandur
# 3960                          1500       Pubs and bars          Bellandur
# ...                            ...                 ...                ...
# 34974                         2000  Drinks & nightlife            MG Road
# 36763                         1400  Drinks & nightlife   Old Airport Road
# 36764                         1300  Drinks & nightlife   Old Airport Road
# 38988                         1500  Drinks & nightlife     Residency Road
# 39373                          200            Delivery      Sarjapur Road
#
# [73 rows x 11 columns]

# %%
df_cleaned=df.drop_duplicates()

# %%
df.shape
# Out:
# (41263, 11)

# %%
df_cleaned.shape
# Out:
# (41190, 11)

# %%
df_cleaned = df_cleaned.convert_dtypes()
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41190 entries, 0 to 41262
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         41190 non-null  string
#  1   online_order                 41190 non-null  string
#  2   book_table                   41190 non-null  string
#  3   Rating                       41190 non-null  Float64
#  4   votes                        41190 non-null  Int64
#  5   location                     41190 non-null  string
#  6   rest_type                    41190 non-null  string
#  7   cuisines                     41190 non-null  string
#  8   approx_cost(for two people)  41190 non-null  Int64
#  9   listed_in(type)              41190 non-null  string
#  10  listed_in(city)              41190 non-null  string
# dtypes: Float64(1), Int64(2), string(8)
# memory usage: 3.9 MB

# %%
df_cleaned.head()
# Out:
#                     name online_order book_table  Rating  votes      location  \
# 0                  Jalsa          Yes        Yes     4.1    775  Banashankari
# 1         Spice Elephant          Yes         No     4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No     3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No     3.7     88  Banashankari
# 4          Grand Village           No         No     3.8    166  Basavanagudi
#
#              rest_type                        cuisines  \
# 0        Casual Dining  North Indian, Mughlai, Chinese
# 1        Casual Dining     Chinese, North Indian, Thai
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian
# 3          Quick Bites      South Indian, North Indian
# 4        Casual Dining        North Indian, Rajasthani
#
#    approx_cost(for two people) listed_in(type) listed_in(city)
# 0                          800          Buffet    Banashankari
# 1                          800          Buffet    Banashankari
# 2                          800          Buffet    Banashankari
# 3                          300          Buffet    Banashankari
# 4                          600          Buffet    Banashankari

# %%
df_cleaned.head()
# Out:
#                     name online_order book_table  Rating  votes      location  \
# 0                  Jalsa          Yes        Yes     4.1    775  Banashankari
# 1         Spice Elephant          Yes         No     4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No     3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No     3.7     88  Banashankari
# 4          Grand Village           No         No     3.8    166  Basavanagudi
#
#              rest_type                        cuisines  \
# 0        Casual Dining  North Indian, Mughlai, Chinese
# 1        Casual Dining     Chinese, North Indian, Thai
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian
# 3          Quick Bites      South Indian, North Indian
# 4        Casual Dining        North Indian, Rajasthani
#
#    approx_cost(for two people) listed_in(type) listed_in(city)
# 0                          800          Buffet    Banashankari
# 1                          800          Buffet    Banashankari
# 2                          800          Buffet    Banashankari
# 3                          300          Buffet    Banashankari
# 4                          600          Buffet    Banashankari

# %%
df_cleaned['Rating']                       = df_cleaned['Rating'].astype(float)
df_cleaned['votes']                        = df_cleaned['votes'].astype(int)
df_cleaned['approx_cost(for two people)']  = df_cleaned['approx_cost(for two people)'].astype(int)

# %%
df_cleaned.head()
# Out:
#                     name online_order book_table  Rating  votes      location  \
# 0                  Jalsa          Yes        Yes     4.1    775  Banashankari
# 1         Spice Elephant          Yes         No     4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No     3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No     3.7     88  Banashankari
# 4          Grand Village           No         No     3.8    166  Basavanagudi
#
#              rest_type                        cuisines  \
# 0        Casual Dining  North Indian, Mughlai, Chinese
# 1        Casual Dining     Chinese, North Indian, Thai
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian
# 3          Quick Bites      South Indian, North Indian
# 4        Casual Dining        North Indian, Rajasthani
#
#    approx_cost(for two people) listed_in(type) listed_in(city)
# 0                          800          Buffet    Banashankari
# 1                          800          Buffet    Banashankari
# 2                          800          Buffet    Banashankari
# 3                          300          Buffet    Banashankari
# 4                          600          Buffet    Banashankari

# %%
df_cleaned.columns = [' '.join(word.capitalize() if i == 0 else word for i, word in enumerate(col.split())) for col in df_cleaned.columns]

df_cleaned.head()
# Out:
#                     Name Online_order Book_table  Rating  Votes      Location  \
# 0                  Jalsa          Yes        Yes     4.1    775  Banashankari
# 1         Spice Elephant          Yes         No     4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No     3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No     3.7     88  Banashankari
# 4          Grand Village           No         No     3.8    166  Basavanagudi
#
#              Rest_type                        Cuisines  \
# 0        Casual Dining  North Indian, Mughlai, Chinese
# 1        Casual Dining     Chinese, North Indian, Thai
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian
# 3          Quick Bites      South Indian, North Indian
# 4        Casual Dining        North Indian, Rajasthani
#
#    Approx_cost(for two people) Listed_in(type) Listed_in(city)
# 0                          800          Buffet    Banashankari
# 1                          800          Buffet    Banashankari
# 2                          800          Buffet    Banashankari
# 3                          300          Buffet    Banashankari
# 4                          600          Buffet    Banashankari

# %%
print(df_cleaned.columns.tolist())
# Out:
# ['Name', 'Online_order', 'Book_table', 'Rating', 'Votes', 'Location', 'Rest_type', 'Cuisines', 'Approx_cost(for two people)', 'Listed_in(type)', 'Listed_in(city)']

# %%
df_cleaned['cuisine_list'] = (
    df_cleaned['Cuisines']
      .str.split(',')
      .apply(lambda lst: [c.strip().title() for c in lst])
)
df_exploded = df_cleaned.explode('cuisine_list').rename(columns={'cuisine_list': 'cuisine'})

# %%
df_exploded.head()
# Out:
#              Name Online_order Book_table  Rating  Votes      Location  \
# 0           Jalsa          Yes        Yes     4.1    775  Banashankari
# 0           Jalsa          Yes        Yes     4.1    775  Banashankari
# 0           Jalsa          Yes        Yes     4.1    775  Banashankari
# 1  Spice Elephant          Yes         No     4.1    787  Banashankari
# 1  Spice Elephant          Yes         No     4.1    787  Banashankari
#
#        Rest_type                        Cuisines  Approx_cost(for two people)  \
# 0  Casual Dining  North Indian, Mughlai, Chinese                          800
# 0  Casual Dining  North Indian, Mughlai, Chinese                          800
# 0  Casual Dining  North Indian, Mughlai, Chinese                          800
# 1  Casual Dining     Chinese, North Indian, Thai                          800
# 1  Casual Dining     Chinese, North Indian, Thai                          800
#
#   Listed_in(type) Listed_in(city)       cuisine
# 0          Buffet    Banashankari  North Indian
# 0          Buffet    Banashankari       Mughlai
# 0          Buffet    Banashankari       Chinese
# 1          Buffet    Banashankari       Chinese
# 1          Buffet    Banashankari  North Indian

# %%
cuisine_stats = (
    df_exploded
      .groupby('Cuisines')
      .agg(
          restaurants_count=('Name', 'nunique'),
          avg_rating=('Rating', 'mean'),
          avg_votes=('Votes', 'mean'),
          avg_price=('Approx_cost(for two people)', 'mean')
      )
      .reset_index()
      .sort_values(by=['avg_rating', 'avg_votes'], ascending=False)
)

# %%
top_cuisines = cuisine_stats[cuisine_stats['restaurants_count'] >= 10].head(10)

# %%
top_restaurants = (
    df_cleaned
      .sort_values(by='Rating', ascending=False)
      .loc[:, ['Name', 'Location', 'Cuisines', 'Rating', 'Votes', 'Approx_cost(for two people)']]
      .head(10)
)

# %%
top_cuisines
# Out:
#                        Cuisines  restaurants_count  avg_rating    avg_votes  \
# 1318                    Italian                 15    4.102083   904.937500
# 1041        Desserts, Beverages                 20    4.068699   213.678862
# 1058        Desserts, Ice Cream                 33    3.921757   121.221757
# 538           Cafe, Continental                 19    3.911921   423.476821
# 977   Continental, North Indian                 11    3.895385  1165.138462
# 622               Cafe, Italian                 12    3.881707   248.548780
# 1883      North Indian, Mughlai                 38    3.879191   599.456647
# 1055        Desserts, Fast Food                 12    3.871053    53.407895
# 768              Chinese, Momos                 41    3.862222   367.982222
# 1302        Ice Cream, Desserts                 41    3.848303   173.464752
#
#         avg_price
# 1318  1550.000000
# 1041   399.390244
# 1058   329.497908
# 538    673.509934
# 977   1332.307692
# 622    553.048780
# 1883  1011.560694
# 1055   338.157895
# 768    768.222222
# 1302   322.454308

# %%
import altair as alt

chart = alt.Chart(top_cuisines).mark_bar().encode(
    x=alt.X('Cuisines:N', sort='-y'),  # 'N' = nominal (categorical)
    y='restaurants_count:Q',          # 'Q' = quantitative (numeric)
    color='Cuisines:N',
    tooltip=['Cuisines', 'restaurants_count', 'avg_rating', 'avg_votes', 'avg_price']
).properties(
    title='Number of Restaurants by Top Cuisine',
    width=600,
    height=400
)

chart
# Out:
# alt.Chart(...)

# %%
import altair as alt

chart_top_restaurants = alt.Chart(top_restaurants).mark_bar().encode(
    x=alt.X('Name:N', sort='-y', title='Restaurant Name'),
    y=alt.Y('Rating:Q', title='Rating'),
    color='Name:N',
    tooltip=['Name', 'Location', 'Cuisines', 'Rating', 'Votes', 'Approx_cost(for two people)']
).properties(
    title='Top 10 Restaurants by Rating',
    width=600,
    height=400
)

chart_top_restaurants
# Out:
# alt.Chart(...)

# %%
top_cuisines_sorted_by_rating = top_cuisines.sort_values(by='avg_rating', ascending=False)

chart_most_liked_cuisine = alt.Chart(top_cuisines_sorted_by_rating).mark_bar().encode(
    x=alt.X('Cuisines:N', sort='-y'),
    y=alt.Y('avg_rating:Q', title='Average Rating'),
    color='Cuisines:N',
    tooltip=['Cuisines', 'restaurants_count', 'avg_rating', 'avg_votes', 'avg_price']
).properties(
    title='Average Rating by Top Cuisine',
    width=600,
    height=400
)

chart_most_liked_cuisine
# Out:
# alt.Chart(...)

# %%
top_cuisines_sorted_by_votes = top_cuisines.sort_values(by='avg_votes', ascending=False)

chart_most_rated_cuisine = alt.Chart(top_cuisines_sorted_by_votes).mark_bar().encode(
    x=alt.X('Cuisines', sort='-y'),
    y=alt.Y('avg_votes', title='Average Votes'),
    color='Cuisines',
    tooltip=['Cuisines', 'restaurants_count', 'avg_rating', 'avg_votes', 'avg_price']
).properties(
    title='Average Votes by Top Cuisine'
)

chart_most_rated_cuisine
# Out:
# alt.Chart(...)
